# %%
# !!pip install -q rouge-score
# Out:
# ['  Preparing metadata (setup.py) ... \x1b[?25l\x1b[?25hdone',
#  '  Building wheel for rouge-score (setup.py) ... \x1b[?25l\x1b[?25hdone']

# %%
import numpy as np
import pandas as pd

# %%
cd /content/drive/MyDrive/NLP project
# Out:
# /content/drive/MyDrive/NLP project

# %%
data = pd.read_csv("/content/drive/MyDrive/NLP project/IMDB Dataset SPANISH.csv")
data.head()
# Out:
#    Unnamed: 0                                          review_en  \
# 0           0  One of the other reviewers has mentioned that ...
# 1           1  A wonderful little production. The filming tec...
# 2           2  I thought this was a wonderful way to spend ti...
# 3           3  Basically there's a family where a little boy ...
# 4           4  Petter Mattei's "Love in the Time of Money" is...
#
#                                            review_es sentiment sentimiento
# 0  Uno de los otros críticos ha mencionado que de...  positive    positivo
# 1  Una pequeña pequeña producción.La técnica de f...  positive    positivo
# 2  Pensé que esta era una manera maravillosa de p...  positive    positivo
# 3  Básicamente, hay una familia donde un niño peq...  negative    negativo
# 4  El "amor en el tiempo" de Petter Mattei es una...  positive    positivo

# %%
data['sentimiento'] = data['sentimiento'].map({'positivo': 1, 'negativo': 0})
data.head()
# Out:
#    Unnamed: 0                                          review_en  \
# 0           0  One of the other reviewers has mentioned that ...
# 1           1  A wonderful little production. The filming tec...
# 2           2  I thought this was a wonderful way to spend ti...
# 3           3  Basically there's a family where a little boy ...
# 4           4  Petter Mattei's "Love in the Time of Money" is...
#
#                                            review_es sentiment  sentimiento
# 0  Uno de los otros críticos ha mencionado que de...  positive            1
# 1  Una pequeña pequeña producción.La técnica de f...  positive            1
# 2  Pensé que esta era una manera maravillosa de p...  positive            1
# 3  Básicamente, hay una familia donde un niño peq...  negative            0
# 4  El "amor en el tiempo" de Petter Mattei es una...  positive            1

# %%
data['sentiment'] = data['sentiment'].map({'positive': 1, 'negative': 0})
data.head()
# Out:
#    Unnamed: 0                                          review_en  \
# 0           0  One of the other reviewers has mentioned that ...
# 1           1  A wonderful little production. The filming tec...
# 2           2  I thought this was a wonderful way to spend ti...
# 3           3  Basically there's a family where a little boy ...
# 4           4  Petter Mattei's "Love in the Time of Money" is...
#
#                                            review_es  sentiment  sentimiento
# 0  Uno de los otros críticos ha mencionado que de...          1            1
# 1  Una pequeña pequeña producción.La técnica de f...          1            1
# 2  Pensé que esta era una manera maravillosa de p...          1            1
# 3  Básicamente, hay una familia donde un niño peq...          0            0
# 4  El "amor en el tiempo" de Petter Mattei es una...          1            1

# %%
corpus_en=data.review_en.tolist()
corpus_spa=data.review_es.tolist()
labels=data.sentimiento.tolist()
print(len(corpus_en))
print(len(corpus_spa))
#print(len(labels))
# Out:
# 50000
# 50000

# %%
#training_size = 40000
#training_sentences = corpus[0:training_size]
#testing_sentences = corpus[training_size:]
#training_labels = labels[0:training_size]
#testing_labels = labels[training_size:]

# %%
 corpus_en = corpus_en.replace('\u202f', ' ').replace('\xa0', ' ')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-a6ac811a35f2> in <module>
# ----> 1 corpus_en = corpus_en.replace('\u202f', ' ').replace('\xa0', ' ')
#
# AttributeError: 'list' object has no attribute 'replace'
